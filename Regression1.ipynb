# %% [markdown]
# <a href="https://colab.research.google.com/github/alibagheribardi/ABlankRepositoryForCloning/blob/main/Regression1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Boston_df = pd.read_csv('sample_data/BostonHousing.csv')
Boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
Boston_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
cols=[4,10,50,56]
Boston_df.loc[cols]
# Out:
#        crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 4   0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 10  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311     15.2
# 50  0.08873  21.0   5.64     0  0.439  5.963  45.7  6.8147    4  243     16.8
# 56  0.02055  85.0   0.74     0  0.410  6.383  35.7  9.1876    2  313     17.3
#
#          b  lstat  medv
# 4   396.90   5.33  36.2
# 10  392.52  20.45  15.0
# 50  395.56  13.45  19.7
# 56  396.90   5.77  24.7

# %% [markdown]
# # New Section

# %%
Boston_df.iloc[3 , 3] = np.nan
Boston_df.loc[:3]
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   NaN  0.458  6.998  45.8  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4

# %%
Boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     505 non-null    float64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
cleaned_df1 = Boston_df.dropna()
cleaned_df1.info()

cleaned_df2 = Boston_df.drop('chas', axis=1)
cleaned_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 505 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     505 non-null    float64
#  1   zn       505 non-null    float64
#  2   indus    505 non-null    float64
#  3   chas     505 non-null    float64
#  4   nox      505 non-null    float64
#  5   rm       505 non-null    float64
#  6   age      505 non-null    float64
#  7   dis      505 non-null    float64
#  8   rad      505 non-null    int64
#  9   tax      505 non-null    int64
#  10  ptratio  505 non-null    float64
#  11  b        505 non-null    float64
#  12  lstat    505 non-null    float64
#  13  medv     505 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 59.2 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
# ...

# %%
import seaborn as sns
import  matplotlib.pyplot as plt
features = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']
sns.pairplot(Boston_df,  y_vars=['medv']  , x_vars = features , height=3 )
plt.show()

# %%
import seaborn as sns
from sklearn.linear_model import LinearRegression


# Define feature columns
features = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']


n_features = len(features)
n_rows = 4
n_cols = 4

fig, axes = plt.subplots(n_rows, n_cols,  figsize=(n_cols * 4, n_rows * 4), squeeze=False)

# Flatten the axes array for easier iteration
axes_flat = axes.flatten()

# Loop through each feature and plot scatter + regression line
for i, feature in enumerate(features):
    ax = axes_flat[i]

    # Scatter plot with regression line
    sns.regplot(data=Boston_df, x=feature, y='medv', ax=ax, scatter_kws={"s": 30}, line_kws={"color": "red"})
    ax.set_title(feature)

# Hide any unused subplots
for j in range(i + 1, len(axes_flat)):
    axes_flat[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
Boston_df[features].corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.056130  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042973 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062343  0.763651 -0.391676  0.644779
# chas    -0.056130 -0.042973  0.062343  1.000000  0.090821  0.091901  0.086143
# nox      0.420972 -0.516604  0.763651  0.090821  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091901 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086143  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.098715 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007780  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.036230  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121465  0.188933 -0.355501  0.261515
# ...

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Generate latitude and longitude values centered around Boston
Boston_df['latitude'] = np.random.uniform(42.23, 42.42, size=len(Boston_df))  # Random latitudes around Boston
Boston_df['longitude'] = np.random.uniform(-71.20, -70.95, size=len(Boston_df))  # Random longitudes around Boston

# Create scatter mapbox plot
fig = px.scatter_mapbox(Boston_df, lat="latitude", lon="longitude",
                        color="medv", size="medv",
                        center={"lat": 42.36, "lon": -71.05},  # Centered on Boston
                        zoom=10, mapbox_style="open-street-map")

# Enlarge the plot with a reasonable size
fig.update_layout(width=1000, height=800)  # Adjust width and height in pixels

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
np.random.seed(42)

# Generate latitude and longitude values centered around Boston
Boston_df['latitude'] = np.random.uniform(42.23, 42.42, size=len(Boston_df))  # Random latitudes around Boston
Boston_df['longitude'] = np.random.uniform(-71.20, -70.95, size=len(Boston_df))  # Random longitudes around Boston

# Create density mapbox plot
fig = px.density_mapbox(Boston_df, lat="latitude", lon="longitude", z="medv",
                        radius=10,  # Size of the circle around each point
                        center={"lat": 42.36, "lon": -71.05},  # Centered on Boston
                        zoom=10, mapbox_style="open-street-map")

# Enlarge the plot with a reasonable size
fig.update_layout(width=1000, height=800)  # Adjust width and height in pixels
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error



# Generate approximate latitude & longitude (since Boston_df doesn't have them)
np.random.seed(42)
Boston_df["latitude"] = np.random.uniform(42.23, 42.42, size=len(Boston_df))
Boston_df["longitude"] = np.random.uniform(-71.20, -70.95, size=len(Boston_df))

# Define KFold cross-validation
num_splits = 5
num_models = 4
kfold = KFold(n_splits=num_splits, random_state=216, shuffle=True)

# Create an array to store RMSE values
rmses = np.zeros((num_models, num_splits))

# Define RMSE function
def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Loop through KFold splits
for i, (train_index, test_index) in enumerate(kfold.split(Boston_df)):
    # Split dataset into training and testing
    train_set = Boston_df.iloc[train_index]
    test_set = Boston_df.iloc[test_index]

    # Target variable
    y_test = test_set["medv"]

    ## 1️⃣ Baseline Model (Mean Prediction)
    baseline_pred = np.full(len(test_set), train_set["medv"].mean())
    rmses[0, i] = root_mean_squared_error(y_test, baseline_pred)

    ## 2️⃣ Simple Linear Regression (SLR) - Using 'rm' (average number of rooms)
    slr = LinearRegression()
    slr.fit(train_set[['rm']], train_set["medv"])
    rmses[1, i] = root_mean_squared_error(y_test, slr.predict(test_set[['rm']]))

    ## 3️⃣ Multiple Linear Regression (MLR) - Using 'rm' & 'lstat'
    mlr = LinearRegression()
    mlr.fit(train_set[['rm', 'lstat']], train_set["medv"])
    rmses[2, i] = root_mean_squared_error(y_test, mlr.predict(test_set[['rm', 'lstat']]))

    ## 4️⃣ K-Nearest Neighbors (KNN) Regression - Using 'latitude' & 'longitude'
    knn = KNeighborsRegressor(n_neighbors=10)
    knn.fit(train_set[['latitude', 'longitude']], train_set["medv"])
    rmses[3, i] = root_mean_squared_error(y_test, knn.predict(test_set[['latitude', 'longitude']]))

# Display the RMSE results
print("RMSE values for each model across folds:\n", rmses)
print("\nMean RMSE for each model:\n", np.mean(rmses, axis=1))
# Out:
# RMSE values for each model across folds:
#  [[ 9.87385063  8.70638202  9.04111052  9.35328297  9.17432364]
#  [ 6.37359037  6.10314882  7.30178445  6.97032104  6.3497146 ]
#  [ 5.38079129  5.52981497  6.2930221   5.5376272   5.1864941 ]
#  [10.33202716  9.35477439  9.57569975 10.22810383  9.49886987]]
#
# Mean RMSE for each model:
#  [9.22978996 6.61971186 5.58554993 9.797895  ]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Model names for visualization
model_names = ["Baseline", "SLR (rm)", "MLR (rm, lstat)", "KNN (lat, lon)"]

# Compute mean RMSE for each model
mean_rmse = np.mean(rmses, axis=1)

# 📊 OPTION 1: Bar Chart - Mean RMSE per Model
plt.figure(figsize=(8, 5))
sns.barplot(x=model_names, y=mean_rmse, hue=model_names, dodge=False, palette="viridis", legend=False)
plt.ylabel("Mean RMSE")
plt.title("Model Performance Comparison (Lower is Better)")
plt.xticks(rotation=15)
plt.show()

# 📊 OPTION 2: Box Plot - RMSE Distribution Across Folds
plt.figure(figsize=(8, 5))
sns.boxplot(data=rmses.T, palette="coolwarm")
plt.xticks(ticks=range(len(model_names)), labels=model_names, rotation=15)
plt.ylabel("RMSE")
plt.title("RMSE Distribution Across K-Folds")
plt.show()
